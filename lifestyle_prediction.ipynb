# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset/lifestyle_synthetic_dataset.csv')
# df.head()
df
# Out:
#         Age  Gender  Height_cm  Weight_kg   BMI  Steps_per_day  \
# 0        37    Male      166.7       58.7  21.1          12000
# 1        68    Male      177.0       87.2  27.8           4000
# 2        56    Male      160.1       60.5  23.6           2000
# 3        49    Male      168.4       62.0  21.9           8000
# 4        26    Male      182.2       83.1  25.0           8000
# ...     ...     ...        ...        ...   ...            ...
# 199995   50  Female      161.7       66.6  25.5           6000
# 199996   51    Male      172.0       83.2  28.1           4000
# 199997   28  Female      154.3       62.3  26.2           8000
# 199998   52  Female      175.6       86.3  28.0          10000
# 199999   18  Female      169.7       57.5  20.0           8000
#
#         Workout_days_per_week  Workout_intensity  Sleep_hours  \
# 0                           2                  1          6.7
# 1                           3                  2          8.2
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Lifestyle_Category'].value_counts()
# Out:
# Lifestyle_Category
# Unhealthy    67105
# Moderate     66605
# Healthy      66290
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      96112
# Female    95850
# Other      8038
# Name: count, dtype: int64

# %%
cols = ['Age','Height_cm','Weight_kg','BMI','Steps_per_day',
                'Workout_days_per_week','Workout_intensity','Sleep_hours',
                'Screen_time_hrs','Water_intake_L','Junk_food_per_week',
                'Alcohol','Smoking','Stress_level','Activity_score',
                'Diet_score','Lifestyle_Score']


plt.figure(figsize=(15,10))
for i, j in enumerate(cols, 1):
    plt.subplot(4,5,i)
    sns.boxplot(y=df[j])
    plt.title(j)
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Age                    200000 non-null  int64
#  1   Gender                 200000 non-null  object
#  2   Height_cm              200000 non-null  float64
#  3   Weight_kg              200000 non-null  float64
#  4   BMI                    200000 non-null  float64
#  5   Steps_per_day          200000 non-null  int64
#  6   Workout_days_per_week  200000 non-null  int64
#  7   Workout_intensity      200000 non-null  int64
#  8   Sleep_hours            200000 non-null  float64
#  9   Screen_time_hrs        200000 non-null  float64
#  10  Water_intake_L         200000 non-null  float64
#  11  Junk_food_per_week     200000 non-null  int64
#  12  Alcohol                200000 non-null  int64
#  13  Smoking                200000 non-null  int64
# ...

# %%
df.sample(2)
# Out:
#         Age  Gender  Height_cm  Weight_kg   BMI  Steps_per_day  \
# 83575    70  Female      172.7       75.0  25.1           6000
# 188273   38    Male      156.4       69.8  28.5           2000
#
#         Workout_days_per_week  Workout_intensity  Sleep_hours  \
# 83575                       1                  2          6.0
# 188273                      2                  1          7.4
#
#         Screen_time_hrs  Water_intake_L  Junk_food_per_week  Alcohol  Smoking  \
# 83575               6.4             6.0                   0        1        0
# 188273              5.6             4.1                   5        0        0
#
#         Stress_level  Activity_score  Diet_score  Lifestyle_Score  \
# 83575            5.0             7.1        8.00             16.6
# 188273           6.6             4.2        5.05              0.0
#
#        Lifestyle_Category
# 83575            Moderate
# 188273          Unhealthy

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df['Gender'] = le.fit_transform(df['Gender'])
df['Lifestyle_Category'] = le.fit_transform(df['Lifestyle_Category'])

# %%
df_cor = df.corr()

plt.figure(figsize=(12,10))
sns.heatmap(df_cor,annot=True,cmap='viridis',fmt='0.02f')
plt.tight_layout()
plt.show()

# %%
df_cor = df_cor.corr()['Lifestyle_Score'].sort_values(ascending=False)
df_cor = df_cor.drop(['Lifestyle_Score','Lifestyle_Category'])

# %%
sns.heatmap(df_cor.to_frame(),annot=True,cmap='viridis')
plt.show()

# %%
x = df[[
    'Sleep_hours',
    'Workout_days_per_week',
    'Workout_intensity',
    'Steps_per_day',
    'Water_intake_L',
    'Stress_level',
    'Screen_time_hrs',
    'Junk_food_per_week'
]]
y_reg = df['Lifestyle_Score']
y_cls = df['Lifestyle_Category']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y_reg,train_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

from sklearn.metrics import r2_score

# %%
models = {
    'LinearRegression' : LinearRegression(),
    'DecisionTreeRegressor' : DecisionTreeRegressor(random_state=42),
    'RandomForestRegressor' : RandomForestRegressor(n_estimators=100,random_state=42),
    'SVR' : SVR(),
    'KNeighborsRegressor' : KNeighborsRegressor()
}

for name,model in models.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    r2 = r2_score(y_test,y_pred)
    print(f'{name} : R2 = {r2}')
# Out:
# LinearRegression : R2 = 0.7416353132118942
# DecisionTreeRegressor : R2 = 0.4646148946614722
# RandomForestRegressor : R2 = 0.7286766004465317
# SVR : R2 = 0.053962143422057074
# KNeighborsRegressor : R2 = 0.6903836985240959

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.fit_transform(x_test)

# %%
models = {
    'LinearRegression' : LinearRegression(),
    'DecisionTreeRegressor' : DecisionTreeRegressor(random_state=42),
    'RandomForestRegressor' : RandomForestRegressor(n_estimators=100,random_state=42),
    'SVR' : SVR(),
    'KNeighborsRegressor' : KNeighborsRegressor()
}

for name,model in models.items():
    model.fit(x_train_sc,y_train)
    y_pred = model.predict(x_test_sc)
    r2 = r2_score(y_test,y_pred)
    print(f'{name} : R2 = {r2}')
# Out:
# LinearRegression : R2 = 0.7415415741796678
# DecisionTreeRegressor : R2 = 0.46556437769441994
# RandomForestRegressor : R2 = 0.7287420079186508
# SVR : R2 = 0.7534656164370734
# KNeighborsRegressor : R2 = 0.6999765608320427

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y_cls,train_size=0.2,random_state=42)

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
models = {
    'LogisticRegression' : LogisticRegression(max_iter=1000),
    'RandomForestClassifier' : RandomForestClassifier(n_estimators=200,random_state=42),
    'SVC' : SVC(),
    'KNeighborsClassifier' : KNeighborsClassifier(n_neighbors=5)
}

for name,model in models.items():
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    acc = accuracy_score(y_test,y_pred)
    print(f'{name} : accuracy = {acc}')
# Out:
# LogisticRegression : accuracy = 0.681025
# RandomForestClassifier : accuracy = 0.6944875
# SVC : accuracy = 0.39830625
# KNeighborsClassifier : accuracy = 0.65873125

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.fit_transform(x_test)

# %%
models = {
    'LogisticRegression' : LogisticRegression(max_iter=1000),
    'RandomForestClassifier' : RandomForestClassifier(n_estimators=200,random_state=42),
    'SVC' : SVC(),
    'KNeighborsClassifier' : KNeighborsClassifier(n_neighbors=5)
}

for name,model in models.items():
    model.fit(x_train_sc,y_train)
    y_pred = model.predict(x_test_sc)
    acc = accuracy_score(y_test,y_pred)
    print(f'{name} : accuracy = {acc}')
# Out:
# LogisticRegression : accuracy = 0.714675
# RandomForestClassifier : accuracy = 0.6945625
# SVC : accuracy = 0.715125
# KNeighborsClassifier : accuracy = 0.66506875

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y_reg,train_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.fit_transform(x_test)

# %%
score_model = SVR()
score_model.fit(x_train_sc,y_train)
# Out:
# SVR()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y_cls,train_size=0.2,random_state=42)


from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.fit_transform(x_test)

# %%
category_model = SVC()
category_model.fit(x_train_sc,y_train)
# Out:
# SVC()

# %%
import joblib

joblib.dump(score_model,'score.pkl')
joblib.dump(category_model,'category.pkl')
joblib.dump(le,'labelencoder.pkl')
# Out:
# ['labelencoder.pkl']
